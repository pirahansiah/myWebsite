# %%
# only Apple Silicon 
# !brew install uv
# Out:
# ==> Fetching downloads for: uv
# ==> Downloading https://ghcr.io/v2/homebrew/core/uv/manifests/0.8.10
# Already downloaded: /Users/farshid/Library/Caches/Homebrew/downloads/355bbf405d9163f954b73622cc57a3e02d4d9c0d322bf6733f1d9863c8ba1509--uv-0.8.10.bottle_manifest.json
# ==> Fetching uv
# ==> Downloading https://ghcr.io/v2/homebrew/core/uv/blobs/sha256:13caeaee1fd899c
# ######################################################################### 100.0%
# ==> Pouring uv--0.8.10.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/uv/0.8.10: 17 files, 37.5MB
# ==> Running `brew cleanup uv`...
# Disable this behaviour by setting `HOMEBREW_NO_INSTALL_CLEANUP=1`.
# Hide these hints with `HOMEBREW_NO_ENV_HINTS=1` (see `man brew`).
# ==> No outdated dependents to upgrade!
# ==> Caveats
# zsh completions have been installed to:
#   /opt/homebrew/share/zsh/site-functions

# %%
# !uv venv .venv
# Out:
# Using CPython 3.12.2 interpreter at: /Users/farshid/projects/install/miniconda3/envs/farshid/bin/python
# Creating virtual environment at: .venv
# Activate with: source .venv/bin/activate

# %%
# !source .venv/bin/activate

# %%
# !uv pip install mlx-llm
# Out:
# Using Python 3.12.2 environment at /Users/farshid/projects/install/miniconda3/envs/farshid
# Resolved 37 packages in 3.21s
# ⠙ Preparing packages... (0/5)
# ⠙ Preparing packages... (0/5)----     0 B/13.04 MiB
# certifi    ------------------------------     0 B/157.44 KiB
# ⠙ Preparing packages... (0/5)----     0 B/13.04 MiB
# idna       ------------------------------     0 B/68.79 KiB
# certifi    ------------------------------     0 B/157.44 KiB
# ⠙ Preparing packages... (0/5)----     0 B/13.04 MiB
# idna       ------------------------------     0 B/68.79 KiB
# certifi    ------------------------------     0 B/157.44 KiB
# ⠙ Preparing packages... (0/5)---- 14.91 KiB/13.04 MiB
# idna       ------------------------------     0 B/68.79 KiB
# certifi    ------------------------------ 14.88 KiB/157.44 KiB
# ⠙ Preparing packages... (0/5)---- 14.91 KiB/13.04 MiB
# idna       ------------------------------ 14.88 KiB/68.79 KiB
# certifi    ------------------------------ 14.88 KiB/157.44 KiB
# ...

# %%
# !uv pip install hf_transfer
# Out:
# Using Python 3.12.2 environment at /Users/farshid/projects/install/miniconda3/envs/farshid
# Resolved 1 package in 415ms
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)-----     0 B/1.29 MiB
# ⠙ Preparing packages... (0/1)----- 16.00 KiB/1.29 MiB
# ⠙ Preparing packages... (0/1)----- 32.00 KiB/1.29 MiB
# ⠙ Preparing packages... (0/1)----- 39.97 KiB/1.29 MiB
# ⠙ Preparing packages... (0/1)----- 55.97 KiB/1.29 MiB
# ⠙ Preparing packages... (0/1)----- 62.40 KiB/1.29 MiB
# ⠙ Preparing packages... (0/1)----- 78.40 KiB/1.29 MiB
# ⠙ Preparing packages... (0/1)----- 94.40 KiB/1.29 MiB
# ⠙ Preparing packages... (0/1)----- 110.40 KiB/1.29 MiB
# ⠙ Preparing packages... (0/1)----- 126.40 KiB/1.29 MiB
# ⠙ Preparing packages... (0/1)----- 142.40 KiB/1.29 MiB
# ⠙ Preparing packages... (0/1)----- 158.40 KiB/1.29 MiB
# ⠙ Preparing packages... (0/1)----- 174.40 KiB/1.29 MiB
# ⠙ Preparing packages... (0/1)----- 190.40 KiB/1.29 MiB
# ⠙ Preparing packages... (0/1)----- 206.40 KiB/1.29 MiB
# ...

# %%
# !export HF_HUB_ENABLE_HF_TRANSFER=1

# %%
# !mlx_lm.chat --model mlx-community/GLM-4.5-Air-4bit -m 10000
"hi, how are you doing today?"
# Out:
# usage: mlx_lm.chat [-h] [--model MODEL] [--adapter-path ADAPTER_PATH]
#                    [--temp TEMP] [--top-p TOP_P] [--seed SEED]
#                    [--max-kv-size MAX_KV_SIZE]
# mlx_lm.chat: error: unrecognized arguments: -m 10000
# 'hi, how are you doing today?'

# %%
# !mlx_lm.chat --model mlx-community/GLM-4.5-Air-4bit -m 10000 "hi, how are you doing today?"
# Out:
# usage: mlx_lm.chat [-h] [--model MODEL] [--adapter-path ADAPTER_PATH]
#                    [--temp TEMP] [--top-p TOP_P] [--seed SEED]
#                    [--max-kv-size MAX_KV_SIZE]
# mlx_lm.chat: error: unrecognized arguments: -m 10000 hi, how are you doing today?

# %%
# !mlx_lm.chat --model mlx-community/GLM-4.5-Air-4bit --temp 0.7 "hi, how are you doing today?"
# Out:
# usage: mlx_lm.chat [-h] [--model MODEL] [--adapter-path ADAPTER_PATH]
#                    [--temp TEMP] [--top-p TOP_P] [--seed SEED]
#                    [--max-kv-size MAX_KV_SIZE]
# mlx_lm.chat: error: unrecognized arguments: hi, how are you doing today?

# %%
# !mlx_lm.chat --model mlx-community/GLM-4.5-Air-4bit --temp 0.7 --prompt "hi, how are you doing today?"
# Out:
# usage: mlx_lm.chat [-h] [--model MODEL] [--adapter-path ADAPTER_PATH]
#                    [--temp TEMP] [--top-p TOP_P] [--seed SEED]
#                    [--max-kv-size MAX_KV_SIZE]
# mlx_lm.chat: error: unrecognized arguments: --prompt hi, how are you doing today?

# %%
# !mlx_lm.chat --model mlx-community/GLM-4.5-Air-4bit --temp 0.7 -- "hi, how are you doing today?"
# Out:
# usage: mlx_lm.chat [-h] [--model MODEL] [--adapter-path ADAPTER_PATH]
#                    [--temp TEMP] [--top-p TOP_P] [--seed SEED]
#                    [--max-kv-size MAX_KV_SIZE]
# mlx_lm.chat: error: unrecognized arguments: -- hi, how are you doing today?
